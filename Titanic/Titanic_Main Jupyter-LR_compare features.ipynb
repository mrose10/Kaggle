# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn import preprocessing 
import seaborn as sns

# %%
# Read in data
filepath = '/Users/maureenkeenan/Desktop/Kaggle/Titanic'
file_train = 'train.csv'
file_test = 'test.csv'
sample = pd.read_csv(os.path.join(filepath,file_train))
data = pd.read_csv(os.path.join(filepath,file_test))

# %%
# Explore data
sample.describe()
sample.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
y = sample.Survived # What we are fitting for
sample.groupby('Survived').Survived.count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import nbimporter
import DataCleanup as dc
# Out:
# Importing Jupyter notebook from DataCleanup.ipynb

# %%
dc.transform_features(sample)
# Out:
# DataCleanup.ipynb:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "    for n in range(len(Surname)):\n",
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex          Age  \
# 0                              Braund, Mr. Owen Harris    male  Young Adult
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        Adult
# 2                               Heikkinen, Miss. Laina  female  Young Adult
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Young Adult
# 4                             Allen, Mr. William Henry    male  Young Adult
# 5                                     Moran, Mr. James    male      Unknown
# 6                              McCarthy, Mr. Timothy J    male        Adult
# 7                       Palsson, Master. Gosta Leonard   child        Child
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  Young Adult
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female     Teenager
# 10                     Sandstrom, Miss. Marguerite Rut   child        Child
# 11                            Bonnell, Miss. Elizabeth  female        Adult
# 12                      Saundercock, Mr. William Henry    male  Young Adult
# 13                         Andersson, Mr. Anders Johan    male        Adult
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female     Teenager
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female        Adult
# 16                                Rice, Master. Eugene   child        Child
# 17                        Williams, Mr. Charles Eugene    male      Unknown
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  Young Adult
# 19                             Masselmani, Mrs. Fatima  female      Unknown
# 20                                Fynney, Mr. Joseph J    male  Young Adult
# 21                               Beesley, Mr. Lawrence    male  Young Adult
# 22                         McGowan, Miss. Anna "Annie"  female     Teenager
# 23                        Sloper, Mr. William Thompson    male  Young Adult
# 24                       Palsson, Miss. Torborg Danira  female        Child
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female        Adult
# 26                             Emir, Mr. Farred Chehab    male      Unknown
# 27                      Fortune, Mr. Charles Alexander    male  Young Adult
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female      Unknown
# 29                                 Todoroff, Mr. Lalio    male      Unknown
# ..                                                 ...     ...          ...
# 861                        Giles, Mr. Frederick Edward    male  Young Adult
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female        Adult
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female      Unknown
# 864                             Gill, Mr. John William    male  Young Adult
# 865                           Bystrom, Mrs. (Karolina)  female        Adult
# 866                       Duran y More, Miss. Asuncion  female  Young Adult
# 867               Roebling, Mr. Washington Augustus II    male  Young Adult
# 868                        van Melkebeke, Mr. Philemon    male      Unknown
# 869                    Johnson, Master. Harold Theodor   child        Child
# 870                                  Balkic, Mr. Cerin    male  Young Adult
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female        Adult
# 872                           Carlsson, Mr. Frans Olof    male  Young Adult
# 873                        Vander Cruyssen, Mr. Victor    male        Adult
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  Young Adult
# 875                   Najib, Miss. Adele Kiamie "Jane"  female     Teenager
# 876                      Gustafsson, Mr. Alfred Ossian    male  Young Adult
# 877                               Petroff, Mr. Nedelio    male  Young Adult
# 878                                 Laleff, Mr. Kristo    male      Unknown
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female        Adult
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  Young Adult
# 881                                 Markun, Mr. Johann    male  Young Adult
# 882                       Dahlberg, Miss. Gerda Ulrika  female  Young Adult
# 883                      Banfield, Mr. Frederick James    male  Young Adult
# 884                             Sutehall, Mr. Henry Jr    male  Young Adult
# 885               Rice, Mrs. William (Margaret Norton)  female        Adult
# 886                              Montvila, Rev. Juozas    male  Young Adult
# 887                       Graham, Miss. Margaret Edith  female  Young Adult
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      Unknown
# 889                              Behr, Mr. Karl Howell    male  Young Adult
# 890                                Dooley, Mr. Patrick    male  Young Adult
#
#      SibSp  Parch            Ticket    Fare Cabin Embarked    Title  TitleKey  \
# 0        1      0         A/5 21171   First     N        S       Mr         4
# 1        1      0          PC 17599  Fourth     C        C      Mrs         2
# 2        0      0  STON/O2. 3101282   First     N        S     Miss         3
# 3        1      0            113803  Fourth     C        S      Mrs         2
# 4        0      0            373450  Second     N        S       Mr         4
# 5        0      0            330877  Second     N        Q       Mr         4
# 6        0      0             17463  Fourth     E        S       Mr         4
# 7        3      1            349909   Third     N        S   Master         5
# 8        0      2            347742  Second     N        S      Mrs         2
# 9        1      0            237736   Third     N        C      Mrs         2
# 10       1      1           PP 9549   Third     G        S     Miss         3
# 11       0      0            113783   Third     C        S     Miss         3
# 12       0      0         A/5. 2151  Second     N        S       Mr         4
# 13       1      5            347082  Fourth     N        S       Mr         4
# 14       0      0            350406   First     N        S     Miss         3
# 15       0      0            248706   Third     N        S      Mrs         2
# 16       4      1            382652   Third     N        Q   Master         5
# 17       0      0            244373  Second     N        S       Mr         4
# 18       1      0            345763   Third     N        S      Mrs         2
# 19       0      0              2649   First     N        C      Mrs         2
# 20       0      0            239865   Third     N        S       Mr         4
# 21       0      0            248698  Second     D        S       Mr         4
# 22       0      0            330923  Second     N        Q     Miss         3
# 23       0      0            113788  Fourth     A        S       Mr         4
# 24       3      1            349909   Third     N        S     Miss         3
# 25       1      5            347077  Fourth     N        S      Mrs         2
# 26       0      0              2631   First     N        C       Mr         4
# 27       3      2             19950  Fourth     C        S       Mr         4
# 28       0      0            330959   First     N        Q     Miss         3
# 29       0      0            349216   First     N        S       Mr         4
# ..     ...    ...               ...     ...   ...      ...      ...       ...
# 861      1      0             28134  Second     N        S       Mr         4
# 862      0      0             17466   Third     D        S      Mrs         2
# 863      8      2          CA. 2343  Fourth     N        S     Miss         3
# 864      0      0            233866  Second     N        S       Mr         4
# 865      0      0            236852  Second     N        S      Mrs         2
# 866      1      0     SC/PARIS 2149  Second     N        C     Miss         3
# 867      0      0          PC 17590  Fourth     A        S       Mr         4
# 868      0      0            345777  Second     N        S       Mr         4
# 869      1      1            347742  Second     N        S   Master         5
# 870      0      0            349248   First     N        S       Mr         4
# 871      1      1             11751  Fourth     D        S      Mrs         2
# 872      0      0               695   First     B        S       Mr         4
# 873      0      0            345765  Second     N        S       Mr         4
# 874      1      0         P/PP 3381   Third     N        C      Mrs         2
# 875      0      0              2667   First     N        C     Miss         3
# 876      0      0              7534  Second     N        S       Mr         4
# 877      0      0            349212   First     N        S       Mr         4
# 878      0      0            349217   First     N        S       Mr         4
# 879      0      1             11767  Fourth     C        C      Mrs         2
# 880      0      1            230433   Third     N        S      Mrs         2
# 881      0      0            349257   First     N        S       Mr         4
# 882      0      0              7552  Second     N        S     Miss         3
# 883      0      0  C.A./SOTON 34068  Second     N        S       Mr         4
# 884      0      0   SOTON/OQ 392076   First     N        S       Mr         4
# 885      0      5            382652   Third     N        Q      Mrs         2
# 886      0      0            211536  Second     N        S      Rev         0
# 887      0      0            112053   Third     B        S     Miss         3
# 888      1      2        W./C. 6607   Third     N        S     Miss         3
# 889      0      0            111369   Third     C        C       Mr         4
# 890      0      0            370376   First     N        Q       Mr         4
#
#              Surname  Family
# 0             Braund       2
# 1            Cumings       1
# 2          Heikkinen       1
# 3           Futrelle       2
# 4              Allen       2
# 5              Moran       3
# 6           McCarthy       1
# 7            Palsson       4
# 8            Johnson       6
# 9             Nasser       2
# 10         Sandstrom       2
# 11           Bonnell       1
# 12       Saundercock       1
# 13         Andersson       9
# 14           Vestrom       1
# 15           Hewlett       1
# 16              Rice       5
# 17          Williams       4
# 18     Vander Planke       3
# 19        Masselmani       1
# 20            Fynney       1
# 21           Beesley       1
# 22           McGowan       1
# 23            Sloper       1
# 24           Palsson       4
# 25           Asplund       4
# 26              Emir       1
# 27           Fortune       4
# 28           O'Dwyer       1
# 29          Todoroff       1
# ..               ...     ...
# 861            Giles       1
# 862            Swift       1
# 863             Sage       7
# 864             Gill       1
# 865          Bystrom       1
# 866     Duran y More       1
# 867         Roebling       1
# 868    van Melkebeke       1
# 869          Johnson       6
# 870           Balkic       1
# 871         Beckwith       2
# 872         Carlsson       2
# 873  Vander Cruyssen       1
# 874          Abelson       2
# 875            Najib       1
# 876       Gustafsson       4
# 877          Petroff       2
# 878           Laleff       1
# 879           Potter       1
# 880          Shelley       1
# 881           Markun       1
# 882         Dahlberg       1
# 883         Banfield       1
# 884         Sutehall       1
# 885             Rice       5
# 886         Montvila       1
# 887           Graham       3
# 888         Johnston       2
# 889             Behr       1
# 890           Dooley       1
#
# [891 rows x 16 columns]

# %%
dc.encode_features(sample)
# Out:
# (     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  5              6         0       3
#  6              7         0       1
#  7              8         0       3
#  8              9         1       3
#  9             10         1       2
#  10            11         1       3
#  11            12         1       1
#  12            13         0       3
#  13            14         0       3
#  14            15         0       3
#  15            16         1       2
#  16            17         0       3
#  17            18         1       2
#  18            19         0       3
#  19            20         1       3
#  20            21         0       2
#  21            22         1       2
#  22            23         1       3
#  23            24         1       1
#  24            25         0       3
#  25            26         1       3
#  26            27         0       3
#  27            28         0       1
#  28            29         1       3
#  29            30         0       3
#  ..           ...       ...     ...
#  861          862         0       2
#  862          863         1       1
#  863          864         0       3
#  864          865         0       2
#  865          866         1       2
#  866          867         1       2
#  867          868         0       1
#  868          869         0       3
#  869          870         1       3
#  870          871         0       3
#  871          872         1       1
#  872          873         0       1
#  873          874         0       3
#  874          875         1       2
#  875          876         1       3
#  876          877         0       3
#  877          878         0       3
#  878          879         0       3
#  879          880         1       1
#  880          881         1       2
#  881          882         0       3
#  882          883         0       3
#  883          884         0       2
#  884          885         0       3
#  885          886         0       3
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name  Sex  Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    2    5      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1    0      1
#  2                               Heikkinen, Miss. Laina    1    5      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    5      1
#  4                             Allen, Mr. William Henry    2    5      0
#  5                                     Moran, Mr. James    2    4      0
#  6                              McCarthy, Mr. Timothy J    2    0      0
#  7                       Palsson, Master. Gosta Leonard    0    1      3
#  8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1    5      0
#  9                  Nasser, Mrs. Nicholas (Adele Achem)    1    3      1
#  10                     Sandstrom, Miss. Marguerite Rut    0    1      1
#  11                            Bonnell, Miss. Elizabeth    1    0      0
#  12                      Saundercock, Mr. William Henry    2    5      0
#  13                         Andersson, Mr. Anders Johan    2    0      1
#  14                Vestrom, Miss. Hulda Amanda Adolfina    1    3      0
#  15                    Hewlett, Mrs. (Mary D Kingcome)     1    0      0
#  16                                Rice, Master. Eugene    0    1      4
#  17                        Williams, Mr. Charles Eugene    2    4      0
#  18   Vander Planke, Mrs. Julius (Emelia Maria Vande...    1    5      1
#  19                             Masselmani, Mrs. Fatima    1    4      0
#  20                                Fynney, Mr. Joseph J    2    5      0
#  21                               Beesley, Mr. Lawrence    2    5      0
#  22                         McGowan, Miss. Anna "Annie"    1    3      0
#  23                        Sloper, Mr. William Thompson    2    5      0
#  24                       Palsson, Miss. Torborg Danira    1    1      3
#  25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...    1    0      1
#  26                             Emir, Mr. Farred Chehab    2    4      0
#  27                      Fortune, Mr. Charles Alexander    2    5      3
#  28                       O'Dwyer, Miss. Ellen "Nellie"    1    4      0
#  29                                 Todoroff, Mr. Lalio    2    4      0
#  ..                                                 ...  ...  ...    ...
#  861                        Giles, Mr. Frederick Edward    2    5      1
#  862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...    1    0      0
#  863                  Sage, Miss. Dorothy Edith "Dolly"    1    4      8
#  864                             Gill, Mr. John William    2    5      0
#  865                           Bystrom, Mrs. (Karolina)    1    0      0
#  866                       Duran y More, Miss. Asuncion    1    5      1
#  867               Roebling, Mr. Washington Augustus II    2    5      0
#  868                        van Melkebeke, Mr. Philemon    2    4      0
#  869                    Johnson, Master. Harold Theodor    0    1      1
#  870                                  Balkic, Mr. Cerin    2    5      0
#  871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)    1    0      1
#  872                           Carlsson, Mr. Frans Olof    2    5      0
#  873                        Vander Cruyssen, Mr. Victor    2    0      0
#  874              Abelson, Mrs. Samuel (Hannah Wizosky)    1    5      1
#  875                   Najib, Miss. Adele Kiamie "Jane"    1    3      0
#  876                      Gustafsson, Mr. Alfred Ossian    2    5      0
#  877                               Petroff, Mr. Nedelio    2    5      0
#  878                                 Laleff, Mr. Kristo    2    4      0
#  879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    1    0      0
#  880       Shelley, Mrs. William (Imanita Parrish Hall)    1    5      0
#  881                                 Markun, Mr. Johann    2    5      0
#  882                       Dahlberg, Miss. Gerda Ulrika    1    5      0
#  883                      Banfield, Mr. Frederick James    2    5      0
#  884                             Sutehall, Mr. Henry Jr    2    5      0
#  885               Rice, Mrs. William (Margaret Norton)    1    0      0
#  886                              Montvila, Rev. Juozas    2    5      0
#  887                       Graham, Miss. Margaret Edith    1    5      0
#  888           Johnston, Miss. Catherine Helen "Carrie"    1    4      1
#  889                              Behr, Mr. Karl Howell    2    5      0
#  890                                Dooley, Mr. Patrick    2    5      0
#
#       Parch            Ticket  Fare  Cabin Embarked  Title  TitleKey  Surname  \
#  0        0         A/5 21171     0      7        S     11         4       73
#  1        0          PC 17599     1      2        C     12         2      136
#  2        0  STON/O2. 3101282     0      7        S      8         3      251
#  3        0            113803     1      2        S     12         2      198
#  4        0            373450     2      7        S     11         4       11
#  5        0            330877     2      7        Q     11         4      409
#  6        0             17463     1      4        S     11         4      378
#  7        1            349909     3      7        S      7         5      463
#  8        2            347742     2      7        S     12         2      292
#  9        0            237736     3      7        C     12         2      426
#  10       1           PP 9549     3      6        S      8         3      537
#  11       0            113783     3      2        S      8         3       65
#  12       0         A/5. 2151     2      7        S     11         4      538
#  13       5            347082     1      7        S     11         4       16
#  14       0            350406     0      7        S      8         3      626
#  15       0            248706     3      7        S     12         2      256
#  16       1            382652     3      7        Q      7         5      505
#  17       0            244373     2      7        S     11         4      647
#  18       0            345763     3      7        S     12         2      625
#  19       0              2649     0      7        C     12         2      375
#  20       0            239865     3      7        S     11         4      199
#  21       0            248698     2      3        S     11         4       51
#  22       0            330923     2      7        Q      8         3      385
#  23       0            113788     1      0        S     11         4      568
#  24       1            349909     3      7        S      8         3      463
#  25       5            347077     1      7        S     12         2       25
#  26       0              2631     0      7        C     11         4      176
#  27       2             19950     1      2        S     11         4      189
#  28       0            330959     0      7        Q      8         3      448
#  29       0            349216     0      7        S     11         4      604
#  ..     ...               ...   ...    ...      ...    ...       ...      ...
#  861      0             28134     2      7        S     11         4      209
#  862      0             17466     3      3        S     12         2      594
#  863      2          CA. 2343     1      7        S      8         3      532
#  864      0            233866     2      7        S     11         4      211
#  865      0            236852     2      7        S     12         2       84
#  866      0     SC/PARIS 2149     2      7        C      8         3      168
#  867      0          PC 17590     1      0        S     11         4      515
#  868      0            345777     2      7        S     11         4      666
#  869      1            347742     2      7        S      7         5      292
#  870      0            349248     0      7        S     11         4       35
#  871      1             11751     1      3        S     12         2       50
#  872      0               695     0      1        S     11         4       97
#  873      0            345765     2      7        S     11         4      624
#  874      0         P/PP 3381     3      7        C     12         2        2
#  875      0              2667     0      7        C      8         3      423
#  876      0              7534     2      7        S     11         4      227
#  877      0            349212     0      7        S     11         4      485
#  878      0            349217     0      7        S     11         4      323
#  879      1             11767     1      2        C     12         2      495
#  880      1            230433     3      7        S     12         2      548
#  881      0            349257     0      7        S     11         4      373
#  882      0              7552     2      7        S      8         3      139
#  883      0  C.A./SOTON 34068     2      7        S     11         4       37
#  884      0   SOTON/OQ 392076     0      7        S     11         4      591
#  885      5            382652     3      7        Q     12         2      505
#  886      0            211536     2      7        S     14         0      406
#  887      0            112053     3      1        S      8         3      221
#  888      2        W./C. 6607     3      7        S      8         3      293
#  889      0            111369     3      2        C     11         4       52
#  890      0            370376     0      7        Q     11         4      159
#
#       Family
#  0         2
#  1         1
#  2         1
#  3         2
#  4         2
#  5         3
#  6         1
#  7         4
#  8         6
#  9         2
#  10        2
#  11        1
#  12        1
#  13        9
#  14        1
#  15        1
#  16        5
#  17        4
#  18        3
#  19        1
#  20        1
#  21        1
#  22        1
#  23        1
#  24        4
#  25        4
#  26        1
#  27        4
#  28        1
#  29        1
#  ..      ...
#  861       1
#  862       1
#  863       7
#  864       1
#  865       1
#  866       1
#  867       1
#  868       1
#  869       6
#  870       1
#  871       2
#  872       2
#  873       1
#  874       2
#  875       1
#  876       4
#  877       2
#  878       1
#  879       1
#  880       1
#  881       1
#  882       1
#  883       1
#  884       1
#  885       5
#  886       1
#  887       3
#  888       2
#  889       1
#  890       1
#
#  [891 rows x 16 columns],
#  {0: 'Abbing',
#   1: 'Abbott',
#   2: 'Abelson',
#   3: 'Adahl',
#   4: 'Adams',
#   5: 'Ahlin',
#   6: 'Aks',
#   7: 'Albimona',
#   8: 'Alexander',
#   9: 'Alhomaki',
#   10: 'Ali',
#   11: 'Allen',
#   12: 'Allison',
#   13: 'Allum',
#   14: 'Andersen-Jensen',
#   15: 'Anderson',
#   16: 'Andersson',
#   17: 'Andreasson',
#   18: 'Andrew',
#   19: 'Andrews',
#   20: 'Angle',
#   21: 'Appleton',
#   22: 'Arnold-Franchi',
#   23: 'Artagaveytia',
#   24: 'Asim',
#   25: 'Asplund',
#   26: 'Astor',
#   27: 'Attalah',
#   28: 'Aubart',
#   29: 'Augustsson',
#   30: 'Ayoub',
#   31: 'Backstrom',
#   32: 'Baclini',
#   33: 'Badt',
#   34: 'Bailey',
#   35: 'Balkic',
#   36: 'Ball',
#   37: 'Banfield',
#   38: 'Barah',
#   39: 'Barbara',
#   40: 'Barber',
#   41: 'Barkworth',
#   42: 'Barton',
#   43: 'Bateman',
#   44: 'Baumann',
#   45: 'Baxter',
#   46: 'Bazzani',
#   47: 'Beane',
#   48: 'Beavan',
#   49: 'Becker',
#   50: 'Beckwith',
#   51: 'Beesley',
#   52: 'Behr',
#   53: 'Bengtsson',
#   54: 'Berglund',
#   55: 'Berriman',
#   56: 'Betros',
#   57: 'Bidois',
#   58: 'Bing',
#   59: 'Birkeland',
#   60: 'Bishop',
#   61: 'Bissette',
#   62: 'Bjornstrom-Steffansson',
#   63: 'Blackwell',
#   64: 'Blank',
#   65: 'Bonnell',
#   66: 'Bostandyeff',
#   67: 'Boulos',
#   68: 'Bourke',
#   69: 'Bowen',
#   70: 'Bowerman',
#   71: 'Bracken',
#   72: 'Bradley',
#   73: 'Braund',
#   74: 'Brewe',
#   75: 'Brocklebank',
#   76: 'Brown',
#   77: 'Bryhl',
#   78: 'Burke',
#   79: 'Burns',
#   80: 'Buss',
#   81: 'Butler',
#   82: 'Butt',
#   83: 'Byles',
#   84: 'Bystrom',
#   85: 'Cacic',
#   86: 'Cairns',
#   87: 'Calderhead',
#   88: 'Caldwell',
#   89: 'Calic',
#   90: 'Cameron',
#   91: 'Campbell',
#   92: 'Canavan',
#   93: 'Cann',
#   94: 'Caram',
#   95: 'Carbines',
#   96: 'Cardeza',
#   97: 'Carlsson',
#   98: 'Carr',
#   99: 'Carrau',
#   100: 'Carter',
#   101: 'Cavendish',
#   102: 'Celotti',
#   103: 'Chaffee',
#   104: 'Chambers',
#   105: 'Chapman',
#   106: 'Charters',
#   107: 'Cherry',
#   108: 'Chibnall',
#   109: 'Chip',
#   110: 'Christmann',
#   111: 'Christy',
#   112: 'Chronopoulos',
#   113: 'Clarke',
#   114: 'Cleaver',
#   115: 'Clifford',
#   116: 'Coelho',
#   117: 'Cohen',
#   118: 'Coleff',
#   119: 'Coleridge',
#   120: 'Collander',
#   121: 'Colley',
#   122: 'Collyer',
#   123: 'Compton',
#   124: 'Connaghton',
#   125: 'Connolly',
#   126: 'Connors',
#   127: 'Cook',
#   128: 'Cor',
#   129: 'Corn',
#   130: 'Coutts',
#   131: 'Coxon',
#   132: 'Crease',
#   133: 'Cribb',
#   134: 'Crosby',
#   135: 'Culumovic',
#   136: 'Cumings',
#   137: 'Cunningham',
#   138: 'Dahl',
#   139: 'Dahlberg',
#   140: 'Dakic',
#   141: 'Daly',
#   142: 'Danbom',
#   143: 'Daniel',
#   144: 'Danoff',
#   145: 'Dantcheff',
#   146: 'Davidson',
#   147: 'Davies',
#   148: 'Davis',
#   149: 'Davison',
#   150: 'Dean',
#   151: 'Denkoff',
#   152: 'Dennis',
#   153: 'Devaney',
#   154: 'Dick',
#   155: 'Dimic',
#   156: 'Dodge',
#   157: 'Doharr',
#   158: 'Doling',
#   159: 'Dooley',
#   160: 'Dorking',
#   161: 'Douglas',
#   162: 'Dowdell',
#   163: 'Downton',
#   164: 'Drazenoic',
#   165: 'Drew',
#   166: 'Duane',
#   167: 'Duff Gordon',
#   168: 'Duran y More',
#   169: 'Edvardsson',
#   170: 'Eitemiller',
#   171: 'Eklund',
#   172: 'Ekstrom',
#   173: 'Elias',
#   174: 'Elsbury',
#   175: 'Emanuel',
#   176: 'Emir',
#   177: 'Endres',
#   178: 'Eustis',
#   179: 'Fahlstrom',
#   180: 'Farrell',
#   181: 'Farthing',
#   182: 'Faunthorpe',
#   183: 'Fischer',
#   184: 'Fleming',
#   185: 'Flynn',
#   186: 'Foo',
#   187: 'Ford',
#   188: 'Foreman',
#   189: 'Fortune',
#   190: 'Fox',
#   191: 'Francatelli',
#   192: 'Frauenthal',
#   193: 'Frolicher',
#   194: 'Frolicher-Stehli',
#   195: 'Frost',
#   196: 'Fry',
#   197: 'Funk',
#   198: 'Futrelle',
#   199: 'Fynney',
#   200: 'Gale',
#   201: 'Gallagher',
#   202: 'Garfirth',
#   203: 'Garside',
#   204: 'Gaskell',
#   205: 'Gavey',
#   206: 'Gee',
#   207: 'Gheorgheff',
#   208: 'Giglio',
#   209: 'Giles',
#   210: 'Gilinski',
#   211: 'Gill',
#   212: 'Gillespie',
#   213: 'Gilnagh',
#   214: 'Givard',
#   215: 'Glynn',
#   216: 'Goldenberg',
#   217: 'Goldschmidt',
#   218: 'Goldsmith',
#   219: 'Goncalves',
#   220: 'Goodwin',
#   221: 'Graham',
#   222: 'Green',
#   223: 'Greenberg',
#   224: 'Greenfield',
#   225: 'Gronnestad',
#   226: 'Guggenheim',
#   227: 'Gustafsson',
#   228: 'Haas',
#   229: 'Hagland',
#   230: 'Hakkarainen',
#   231: 'Hale',
#   232: 'Hamalainen',
#   233: 'Hampe',
#   234: 'Hanna',
#   235: 'Hansen',
#   236: 'Harder',
#   237: 'Harknett',
#   238: 'Harmer',
#   239: 'Harper',
#   240: 'Harrington',
#   241: 'Harris',
#   242: 'Harrison',
#   243: 'Hart',
#   244: 'Hassab',
#   245: 'Hassan',
#   246: 'Hawksford',
#   247: 'Hays',
#   248: 'Healy',
#   249: 'Hedman',
#   250: 'Hegarty',
#   251: 'Heikkinen',
#   252: 'Heininen',
#   253: 'Hendekovic',
#   254: 'Henry',
#   255: 'Herman',
#   256: 'Hewlett',
#   257: 'Hickman',
#   258: 'Hippach',
#   259: 'Hirvonen',
#   260: 'Hocking',
#   261: 'Hodges',
#   262: 'Hogeboom',
#   263: 'Hold',
#   264: 'Holm',
#   265: 'Holverson',
#   266: 'Homer',
#   267: 'Honkanen',
#   268: 'Hood',
#   269: 'Horgan',
#   270: 'Hosono',
#   271: 'Hoyt',
#   272: 'Humblen',
#   273: 'Hunt',
#   274: 'Ibrahim Shawah',
#   275: 'Icard',
#   276: 'Ilett',
#   277: 'Ilmakangas',
#   278: 'Isham',
#   279: 'Ivanoff',
#   280: 'Jacobsohn',
#   281: 'Jalsevac',
#   282: 'Jansson',
#   283: 'Jardin',
#   284: 'Jarvis',
#   285: 'Jenkin',
#   286: 'Jensen',
#   287: 'Jermyn',
#   288: 'Jerwan',
#   289: 'Johannesen-Bratthammer',
#   290: 'Johanson',
#   291: 'Johansson',
#   292: 'Johnson',
#   293: 'Johnston',
#   294: 'Jonkoff',
#   295: 'Jonsson',
#   296: 'Jussila',
#   297: 'Kallio',
#   298: 'Kalvik',
#   299: 'Kantor',
#   300: 'Karaic',
#   301: 'Karlsson',
#   302: 'Karun',
#   303: 'Kassem',
#   304: 'Keane',
#   305: 'Keefe',
#   306: 'Kelly',
#   307: 'Kent',
#   308: 'Kenyon',
#   309: 'Kiernan',
#   310: 'Kilgannon',
#   311: 'Kimball',
#   312: 'Kink',
#   313: 'Kink-Heilmann',
#   314: 'Kirkland',
#   315: 'Klaber',
#   316: 'Klasen',
#   317: 'Knight',
#   318: 'Kraeff',
#   319: 'Kvillner',
#   320: 'Lahoud',
#   321: 'Lahtinen',
#   322: 'Laitinen',
#   323: 'Laleff',
#   324: 'Lam',
#   325: 'Landergren',
#   326: 'Lang',
#   327: 'Laroche',
#   328: 'Larsson',
#   329: 'LeRoy',
#   330: 'Leader',
#   331: 'Leeni',
#   332: 'Lefebre',
#   333: 'Lehmann',
#   334: 'Leinonen',
#   335: 'Leitch',
#   336: 'Lemberopolous',
#   337: 'Lemore',
#   338: 'Lennon',
#   339: 'Leonard',
#   340: 'Lester',
#   341: 'Lesurer',
#   342: 'Levy',
#   343: 'Lewy',
#   344: 'Leyson',
#   345: 'Lievens',
#   346: 'Lindahl',
#   347: 'Lindblom',
#   348: 'Lindell',
#   349: 'Lindqvist',
#   350: 'Lines',
#   351: 'Ling',
#   352: 'Lobb',
#   353: 'Long',
#   354: 'Longley',
#   355: 'Louch',
#   356: 'Lovell',
#   357: 'Lulic',
#   358: 'Lundahl',
#   359: 'Lurette',
#   360: 'Mack',
#   361: 'Madigan',
#   362: 'Madill',
#   363: 'Madsen',
#   364: 'Maenpaa',
#   365: 'Maioni',
#   366: 'Maisner',
#   367: 'Mallet',
#   368: 'Mamee',
#   369: 'Mangan',
#   370: 'Mannion',
#   371: 'Marechal',
#   372: 'Markoff',
#   373: 'Markun',
#   374: 'Marvin',
#   375: 'Masselmani',
#   376: 'Matthews',
#   377: 'Mayne',
#   378: 'McCarthy',
#   379: 'McCormack',
#   380: 'McCoy',
#   381: 'McDermott',
#   382: 'McEvoy',
#   383: 'McGough',
#   384: 'McGovern',
#   385: 'McGowan',
#   386: 'McKane',
#   387: 'McMahon',
#   388: 'McNamee',
#   389: 'Meanwell',
#   390: 'Meek',
#   391: 'Mellinger',
#   392: 'Mellors',
#   393: 'Meo',
#   394: 'Mernagh',
#   395: 'Meyer',
#   396: 'Millet',
#   397: 'Milling',
#   398: 'Minahan',
#   399: 'Mineff',
#   400: 'Mionoff',
#   401: 'Mitchell',
#   402: 'Mitkoff',
#   403: 'Mockler',
#   404: 'Moen',
#   405: 'Molson',
#   406: 'Montvila',
#   407: 'Moor',
#   408: 'Moore',
#   409: 'Moran',
#   410: 'Moraweck',
#   411: 'Morley',
#   412: 'Morrow',
#   413: 'Moss',
#   414: 'Moubarek',
#   415: 'Moussa',
#   416: 'Moutal',
#   417: 'Mudd',
#   418: 'Mullens',
#   419: 'Murdlin',
#   420: 'Murphy',
#   421: 'Myhrman',
#   422: 'Naidenoff',
#   423: 'Najib',
#   424: 'Nakid',
#   425: 'Nankoff',
#   426: 'Nasser',
#   427: 'Natsch',
#   428: 'Navratil',
#   429: 'Nenkoff',
#   430: 'Newell',
#   431: 'Newsom',
#   432: 'Nicholls',
#   433: 'Nicholson',
#   434: 'Nicola-Yarred',
#   435: 'Nilsson',
#   436: 'Nirva',
#   437: 'Niskanen',
#   438: 'Norman',
#   439: 'Nosworthy',
#   440: 'Novel',
#   441: 'Nye',
#   442: 'Nysten',
#   443: 'Nysveen',
#   444: "O'Brien",
#   445: "O'Connell",
#   446: "O'Connor",
#   447: "O'Driscoll",
#   448: "O'Dwyer",
#   449: "O'Leary",
#   450: "O'Sullivan",
#   451: 'Odahl',
#   452: 'Ohman',
#   453: 'Olsen',
#   454: 'Olsson',
#   455: 'Olsvigen',
#   456: 'Oreskovic',
#   457: 'Osen',
#   458: 'Osman',
#   459: 'Ostby',
#   460: 'Otter',
#   461: 'Padro y Manent',
#   462: 'Pain',
#   463: 'Palsson',
#   464: 'Panula',
#   465: 'Parkes',
#   466: 'Parr',
#   467: 'Parrish',
#   468: 'Partner',
#   469: 'Pasic',
#   470: 'Patchett',
#   471: 'Paulner',
#   472: 'Pavlovic',
#   473: 'Pears',
#   474: 'Peduzzi',
#   475: 'Pekoniemi',
#   476: 'Penasco y Castellana',
#   477: 'Pengelly',
#   478: 'Perkin',
#   479: 'Pernot',
#   480: 'Perreault',
#   481: 'Persson',
#   482: 'Peter',
#   483: 'Peters',
#   484: 'Petranec',
#   485: 'Petroff',
#   486: 'Petterson',
#   487: 'Pettersson',
#   488: 'Peuchen',
#   489: 'Phillips',
#   490: 'Pickard',
#   491: 'Pinsky',
#   492: 'Plotcharsky',
#   493: 'Ponesell',
#   494: 'Porter',
#   495: 'Potter',
#   496: 'Quick',
#   497: 'Radeff',
#   498: 'Razi',
#   499: 'Reed',
#   500: 'Reeves',
#   501: 'Rekic',
#   502: 'Renouf',
#   503: 'Reuchlin',
#   504: 'Reynaldo',
#   505: 'Rice',
#   506: 'Richard',
#   507: 'Richards',
#   508: 'Ridsdale',
#   509: 'Ringhini',
#   510: 'Rintamaki',
#   511: 'Risien',
#   512: 'Robbins',
#   513: 'Robert',
#   514: 'Robins',
#   515: 'Roebling',
#   516: 'Rogers',
#   517: 'Romaine',
#   518: 'Rommetvedt',
#   519: 'Rood',
#   520: 'Rosblom',
#   521: 'Ross',
#   522: 'Rothes',
#   523: 'Rothschild',
#   524: 'Rouse',
#   525: 'Rugg',
#   526: 'Rush',
#   527: 'Ryan',
#   528: 'Ryerson',
#   529: 'Saad',
#   530: 'Saalfeld',
#   531: 'Sadlier',
#   532: 'Sage',
#   533: 'Sagesser',
#   534: 'Salkjelsvik',
#   535: 'Salonen',
#   536: 'Samaan',
#   537: 'Sandstrom',
#   538: 'Saundercock',
#   539: 'Sawyer',
#   540: 'Scanlan',
#   541: 'Sdycoff',
#   542: 'Sedgwick',
#   543: 'Serepeca',
#   544: 'Seward',
#   545: 'Sharp',
#   546: 'Sheerlinck',
#   547: 'Shellard',
#   548: 'Shelley',
#   549: 'Shorney',
#   550: 'Shutes',
#   551: 'Silven',
#   552: 'Silverthorne',
#   553: 'Silvey',
#   554: 'Simmons',
#   555: 'Simonius-Blumer',
#   556: 'Sinkkonen',
#   557: 'Sirayanian',
#   558: 'Sirota',
#   559: 'Sivic',
#   560: 'Sivola',
#   561: 'Sjoblom',
#   562: 'Sjostedt',
#   563: 'Skoog',
#   564: 'Slabenoff',
#   565: 'Slayter',
#   566: 'Slemen',
#   567: 'Slocovski',
#   568: 'Sloper',
#   569: 'Smart',
#   570: 'Smiljanic',
#   571: 'Smith',
#   572: 'Sobey',
#   573: 'Soholt',
#   574: 'Somerton',
#   575: 'Spedden',
#   576: 'Spencer',
#   577: 'Stahelin-Maeglin',
#   578: 'Staneff',
#   579: 'Stankovic',
#   580: 'Stanley',
#   581: 'Stead',
#   582: 'Stephenson',
#   583: 'Stewart',
#   584: 'Stone',
#   585: 'Stoytcheff',
#   586: 'Strandberg',
#   587: 'Stranden',
#   588: 'Strom',
#   589: 'Sunderland',
#   590: 'Sundman',
#   591: 'Sutehall',
#   592: 'Sutton',
#   593: 'Svensson',
#   594: 'Swift',
#   595: 'Taussig',
#   596: 'Taylor',
#   597: 'Thayer',
#   598: 'Theobald',
#   599: 'Thomas',
#   600: 'Thorne',
#   601: 'Thorneycroft',
#   602: 'Tikkanen',
#   603: 'Tobin',
#   604: 'Todoroff',
#   605: 'Tomlin',
#   606: 'Toomey',
#   607: 'Torber',
#   608: 'Tornquist',
#   609: 'Toufik',
#   610: 'Touma',
#   611: 'Troupiansky',
#   612: 'Trout',
#   613: 'Troutt',
#   614: 'Turcin',
#   615: 'Turja',
#   616: 'Turkula',
#   617: 'Turpin',
#   618: 'Uruchurtu',
#   619: 'Van Impe',
#   620: 'Van der hoef',
#   621: 'Vande Velde',
#   622: 'Vande Walle',
#   623: 'Vanden Steen',
#   624: 'Vander Cruyssen',
#   625: 'Vander Planke',
#   626: 'Vestrom',
#   627: 'Vovk',
#   628: 'Waelens',
#   629: 'Walker',
#   630: 'Ward',
#   631: 'Warren',
#   632: 'Watson',
#   633: 'Watt',
#   634: 'Webber',
#   635: 'Weir',
#   636: 'Weisz',
#   637: 'Wells',
#   638: 'West',
#   639: 'Wheadon',
#   640: 'White',
#   641: 'Wick',
#   642: 'Widegren',
#   643: 'Widener',
#   644: 'Wiklund',
#   645: 'Wilhelms',
#   646: 'Willey',
#   647: 'Williams',
#   648: 'Williams-Lambert',
#   649: 'Windelov',
#   650: 'Wiseman',
#   651: 'Woolner',
#   652: 'Wright',
#   653: 'Yasbeck',
#   654: 'Young',
#   655: 'Youseff',
#   656: 'Yousif',
#   657: 'Yousseff',
#   658: 'Yrois',
#   659: 'Zabour',
#   660: 'Zimmerman',
#   661: 'de Messemaeker',
#   662: 'de Mulder',
#   663: 'de Pelsmaeker',
#   664: 'del Carlo',
#   665: 'van Billiard',
#   666: 'van Melkebeke'})

# %%
# Do a quick subset of features
quick_features = ['Sex','Age','Pclass','SibSp','Cabin','TitleKey','Fare','Embarked']
X = sample.drop(columns = ['Survived'])
y = sample.Survived

# %%
# Define subfeatures
features_1 = ['Sex','Age','Pclass']
features_2 = ['Sex','Age','Pclass','SibSp','Parch']
features_3 = ['Sex','Age','Pclass','Family']
features_4 = ['Sex','Age','Pclass','SibSp','Parch','Fare']
features_5 = ['Sex','Age','Pclass','SibSp','Parch','Fare','Title']

features = [features_1, features_2, features_3, features_4, features_5]

# %%
# Break off validation set from training data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state=0)

print(len(X_train))
# Out:
# 712

# %%
# import the class
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# Create base model
model = LogisticRegression(solver='lbfgs',C = 1,max_iter=300)

for i in range(0, len(features)):
    model.fit(X_train[features[i]], y_train)
    y_pred = model.predict(X_test[features[i]])
    
    # get stats
    accuracy = metrics.accuracy_score(y_test,y_pred)
    cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
    print("Model ",i+1,"accuracy: ", accuracy.round(2), " CNF: \n", cnf_matrix)
# Out:
# Model  1 accuracy:  0.84  CNF:
#  [[97 13]
#  [16 53]]
# Model  2 accuracy:  0.81  CNF:
#  [[96 14]
#  [20 49]]
# Model  3 accuracy:  0.83  CNF:
#  [[97 13]
#  [18 51]]
# Model  4 accuracy:  0.81  CNF:
#  [[95 15]
#  [19 50]]
# Model  5 accuracy:  0.82  CNF:
#  [[96 14]
#  [19 50]]

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred).round(2))
print("Precision:",metrics.precision_score(y_test, y_pred).round(2))
print("Recall:",metrics.recall_score(y_test, y_pred).round(2))
# Out:
# Accuracy: 0.79
# Precision: 0.72
# Recall: 0.72

# %%
differences = y_pred-y_test
FN = differences[differences == -1].index
sample.iloc[FN,:]

# %%
FP = differences[differences == 1].index
sample.iloc[FP,:]

# %%
# Check out the ROC curve
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# Ok, how do we improve?

# %%
# Do this for the test set
dc.transform_features(data)
dc.encode_features(data)
X = data[quick_features]
predictions =logreg.predict(X)

# Save into output file
ids = data['PassengerId']

output = pd.DataFrame({ 'PassengerId' : ids, 'Survived': predictions })
output.to_csv('titanic-predictions_logistic.csv', index = False)
output.head()
