# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn import preprocessing 
import seaborn as sns

# %%
# Read in data
filepath = '/Users/maureenkeenan/Desktop/Kaggle/Titanic'
file_train = 'train.csv'
file_test = 'test.csv'
sample = pd.read_csv(os.path.join(filepath,file_train))
data = pd.read_csv(os.path.join(filepath,file_test))

# %%
# Explore data
sample.describe()
sample.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
y = sample.Survived # What we are fitting for
sample.groupby('Survived').Survived.count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import nbimporter
import DataCleanup as dc
# Out:
# Importing Jupyter notebook from DataCleanup.ipynb

# %%
dc.transform_features(sample)
# Out:
# DataCleanup.ipynb:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "        title.append(tmp[-1].split('.')[0]) #or to combine use regexp and search\n",
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex          Age  \
# 0                              Braund, Mr. Owen Harris    male      Student
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        Adult
# 2                               Heikkinen, Miss. Laina  female  Young Adult
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Young Adult
# 4                             Allen, Mr. William Henry    male  Young Adult
# 5                                     Moran, Mr. James    male      Unknown
# 6                              McCarthy, Mr. Timothy J    male        Adult
# 7                       Palsson, Master. Gosta Leonard   child         Baby
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  Young Adult
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female     Teenager
# 10                     Sandstrom, Miss. Marguerite Rut   child         Baby
# 11                            Bonnell, Miss. Elizabeth  female        Adult
# 12                      Saundercock, Mr. William Henry    male      Student
# 13                         Andersson, Mr. Anders Johan    male        Adult
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female     Teenager
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female        Adult
# 16                                Rice, Master. Eugene   child         Baby
# 17                        Williams, Mr. Charles Eugene    male      Unknown
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  Young Adult
# 19                             Masselmani, Mrs. Fatima  female      Unknown
# 20                                Fynney, Mr. Joseph J    male  Young Adult
# 21                               Beesley, Mr. Lawrence    male  Young Adult
# 22                         McGowan, Miss. Anna "Annie"  female     Teenager
# 23                        Sloper, Mr. William Thompson    male  Young Adult
# 24                       Palsson, Miss. Torborg Danira  female        Child
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female        Adult
# 26                             Emir, Mr. Farred Chehab    male      Unknown
# 27                      Fortune, Mr. Charles Alexander    male      Student
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female      Unknown
# 29                                 Todoroff, Mr. Lalio    male      Unknown
# ..                                                 ...     ...          ...
# 861                        Giles, Mr. Frederick Edward    male      Student
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female        Adult
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female      Unknown
# 864                             Gill, Mr. John William    male      Student
# 865                           Bystrom, Mrs. (Karolina)  female        Adult
# 866                       Duran y More, Miss. Asuncion  female  Young Adult
# 867               Roebling, Mr. Washington Augustus II    male  Young Adult
# 868                        van Melkebeke, Mr. Philemon    male      Unknown
# 869                    Johnson, Master. Harold Theodor   child         Baby
# 870                                  Balkic, Mr. Cerin    male  Young Adult
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female        Adult
# 872                           Carlsson, Mr. Frans Olof    male  Young Adult
# 873                        Vander Cruyssen, Mr. Victor    male        Adult
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  Young Adult
# 875                   Najib, Miss. Adele Kiamie "Jane"  female     Teenager
# 876                      Gustafsson, Mr. Alfred Ossian    male      Student
# 877                               Petroff, Mr. Nedelio    male      Student
# 878                                 Laleff, Mr. Kristo    male      Unknown
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female        Adult
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female      Student
# 881                                 Markun, Mr. Johann    male  Young Adult
# 882                       Dahlberg, Miss. Gerda Ulrika  female      Student
# 883                      Banfield, Mr. Frederick James    male  Young Adult
# 884                             Sutehall, Mr. Henry Jr    male      Student
# 885               Rice, Mrs. William (Margaret Norton)  female        Adult
# 886                              Montvila, Rev. Juozas    male  Young Adult
# 887                       Graham, Miss. Margaret Edith  female      Student
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      Unknown
# 889                              Behr, Mr. Karl Howell    male  Young Adult
# 890                                Dooley, Mr. Patrick    male  Young Adult
#
#      SibSp  Parch            Ticket    Fare Cabin Embarked    Title
# 0        1      0         A/5 21171   First     N        S       Mr
# 1        1      0          PC 17599  Fourth     C        C      Mrs
# 2        0      0  STON/O2. 3101282   First     N        S     Miss
# 3        1      0            113803  Fourth     C        S      Mrs
# 4        0      0            373450  Second     N        S       Mr
# 5        0      0            330877  Second     N        Q       Mr
# 6        0      0             17463  Fourth     E        S       Mr
# 7        3      1            349909   Third     N        S   Master
# 8        0      2            347742  Second     N        S      Mrs
# 9        1      0            237736   Third     N        C      Mrs
# 10       1      1           PP 9549   Third     G        S     Miss
# 11       0      0            113783   Third     C        S     Miss
# 12       0      0         A/5. 2151  Second     N        S       Mr
# 13       1      5            347082  Fourth     N        S       Mr
# 14       0      0            350406   First     N        S     Miss
# 15       0      0            248706   Third     N        S      Mrs
# 16       4      1            382652   Third     N        Q   Master
# 17       0      0            244373  Second     N        S       Mr
# 18       1      0            345763   Third     N        S      Mrs
# 19       0      0              2649   First     N        C      Mrs
# 20       0      0            239865   Third     N        S       Mr
# 21       0      0            248698  Second     D        S       Mr
# 22       0      0            330923  Second     N        Q     Miss
# 23       0      0            113788  Fourth     A        S       Mr
# 24       3      1            349909   Third     N        S     Miss
# 25       1      5            347077  Fourth     N        S      Mrs
# 26       0      0              2631   First     N        C       Mr
# 27       3      2             19950  Fourth     C        S       Mr
# 28       0      0            330959   First     N        Q     Miss
# 29       0      0            349216   First     N        S       Mr
# ..     ...    ...               ...     ...   ...      ...      ...
# 861      1      0             28134  Second     N        S       Mr
# 862      0      0             17466   Third     D        S      Mrs
# 863      8      2          CA. 2343  Fourth     N        S     Miss
# 864      0      0            233866  Second     N        S       Mr
# 865      0      0            236852  Second     N        S      Mrs
# 866      1      0     SC/PARIS 2149  Second     N        C     Miss
# 867      0      0          PC 17590  Fourth     A        S       Mr
# 868      0      0            345777  Second     N        S       Mr
# 869      1      1            347742  Second     N        S   Master
# 870      0      0            349248   First     N        S       Mr
# 871      1      1             11751  Fourth     D        S      Mrs
# 872      0      0               695   First     B        S       Mr
# 873      0      0            345765  Second     N        S       Mr
# 874      1      0         P/PP 3381   Third     N        C      Mrs
# 875      0      0              2667   First     N        C     Miss
# 876      0      0              7534  Second     N        S       Mr
# 877      0      0            349212   First     N        S       Mr
# 878      0      0            349217   First     N        S       Mr
# 879      0      1             11767  Fourth     C        C      Mrs
# 880      0      1            230433   Third     N        S      Mrs
# 881      0      0            349257   First     N        S       Mr
# 882      0      0              7552  Second     N        S     Miss
# 883      0      0  C.A./SOTON 34068  Second     N        S       Mr
# 884      0      0   SOTON/OQ 392076   First     N        S       Mr
# 885      0      5            382652   Third     N        Q      Mrs
# 886      0      0            211536  Second     N        S      Rev
# 887      0      0            112053   Third     B        S     Miss
# 888      1      2        W./C. 6607   Third     N        S     Miss
# 889      0      0            111369   Third     C        C       Mr
# 890      0      0            370376   First     N        Q       Mr
#
# [891 rows x 13 columns]

# %%
[sample, feature_mappings] = dc.encode_features(sample)

# %%
# Do a quick subset of features
quick_features = ['Sex','Fare','Parch']
X = sample[quick_features]
y = sample.Survived

# %%
# Split into train and test (here the cv)
from sklearn.model_selection import train_test_split

num_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = num_test)

# %%
print('The size of X is: ',len(X))
print('The size of train is: ',len(X_train))
print('The size of test is: ',len(X_test))
# Out:
# The size of X is:  891
# The size of train is:  712
# The size of test is:  179

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(solver='lbfgs')

# fit the model with data
logreg.fit(X_train,y_train)

#
y_pred=logreg.predict(X_test)

# %%
# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[90, 19],
#        [16, 54]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred).round(2))
print("Precision:",metrics.precision_score(y_test, y_pred).round(2))
print("Recall:",metrics.recall_score(y_test, y_pred).round(2))
# Out:
# Accuracy: 0.8
# Precision: 0.74
# Recall: 0.77

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
